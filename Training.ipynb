# %%
import pandas as pd
import numpy as np

# %%
train_df=pd.read_csv("train.csv")
test_df=pd.read_csv("test.csv")

# %%
date_time=pd.DataFrame()

# %%
train_df['datetime']=pd.to_datetime(train_df.datetime)
train_df['datetime'].head()
# Out:
# 0   2019-08-04 14:33:20
# 1   2018-11-05 10:13:20
# 2   2019-09-14 14:03:20
# 3   2018-12-25 15:33:20
# 4   2019-05-04 03:13:20
# Name: datetime, dtype: datetime64[ns]

# %%
train_df['datetime']=pd.to_datetime(train_df.datetime,format="%Y-%M-%D %H:%M:%S")
train_df['datetime'].head()
# Out:
# 0   2019-08-04 14:33:20
# 1   2018-11-05 10:13:20
# 2   2019-09-14 14:03:20
# 3   2018-12-25 15:33:20
# 4   2019-05-04 03:13:20
# Name: datetime, dtype: datetime64[ns]

# %%
df1=train_df['datetime']

# %%
date_time['Y']=train_df['datetime'].dt.year

# %%
date_time['M']=train_df['datetime'].dt.month

# %%
date_time['D']=train_df['datetime'].dt.day

# %%
date_time['H']=train_df['datetime'].dt.hour

# %%
date_time['Min']=train_df['datetime'].dt.minute

# %%
date_time['S']=train_df['datetime'].dt.second

# %%
df1=pd.concat([train_df,date_time],axis='columns')
df1.head()
# Out:
#   tracking_id            datetime  wind_speed(m/s)  \
# 0    WM_33725 2019-08-04 14:33:20        94.820023
# 1      WM_698 2018-11-05 10:13:20       241.832734
# 2    WM_39146 2019-09-14 14:03:20        95.484724
# 3     WM_6757 2018-12-25 15:33:20       238.819424
# 4    WM_21521 2019-05-04 03:13:20        10.722890
#
#    atmospheric_temperature(°C)  shaft_temperature(°C)  blades_angle(°)  \
# 0                   -99.000000              41.723019        -0.903423
# 1                    27.764785             -99.000000       -99.000000
# 2                          NaN              41.855473        12.652763
# 3                   -99.000000              45.443914        15.115323
# 4                          NaN              41.981183         1.715696
#
#    gearbox_temperature(°C)  engine_temperature(°C)  motor_torque(N-m)  \
# 0                82.410573               42.523015        2563.124522
# 1                44.104919               46.258870        2372.384119
# ...

# %%
df1.tracking_id=df1.tracking_id.apply(lambda x:x[3:])
df1.head()
# Out:
#   tracking_id            datetime  wind_speed(m/s)  \
# 0       33725 2019-08-04 14:33:20        94.820023
# 1         698 2018-11-05 10:13:20       241.832734
# 2       39146 2019-09-14 14:03:20        95.484724
# 3        6757 2018-12-25 15:33:20       238.819424
# 4       21521 2019-05-04 03:13:20        10.722890
#
#    atmospheric_temperature(°C)  shaft_temperature(°C)  blades_angle(°)  \
# 0                   -99.000000              41.723019        -0.903423
# 1                    27.764785             -99.000000       -99.000000
# 2                          NaN              41.855473        12.652763
# 3                   -99.000000              45.443914        15.115323
# 4                          NaN              41.981183         1.715696
#
#    gearbox_temperature(°C)  engine_temperature(°C)  motor_torque(N-m)  \
# 0                82.410573               42.523015        2563.124522
# 1                44.104919               46.258870        2372.384119
# ...

# %%
df1=df1.drop('datetime',axis='columns')
df1.head()
# Out:
#   tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 0       33725        94.820023                   -99.000000
# 1         698       241.832734                    27.764785
# 2       39146        95.484724                          NaN
# 3        6757       238.819424                   -99.000000
# 4       21521        10.722890                          NaN
#
#    shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 0              41.723019        -0.903423                82.410573
# 1             -99.000000       -99.000000                44.104919
# 2              41.855473        12.652763                42.322098
# 3              45.443914        15.115323                44.759643
# 4              41.981183         1.715696               -17.616459
#
#    engine_temperature(°C)  motor_torque(N-m)  generator_temperature(°C)  \
# 0               42.523015        2563.124522                  76.665560
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel('atmospheric_temperature(°C)')
plt.ylabel('windmill_generated_power(kW/h)	')
plt.scatter(df1['atmospheric_temperature(°C)'],df1['windmill_generated_power(kW/h)'])
# Out:
# /home/rishi/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/rishi/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df2=df1[df1['atmospheric_temperature(°C)']>=0]
df2.head()
# Out:
#    tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 1          698       241.832734                    27.764785
# 5        17873        93.769973                    30.326226
# 7        30330        48.737826                    12.716815
# 9        28915       283.789329                    18.887932
# 11        2506        92.774351                    15.843846
#
#     shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 1              -99.000000       -99.000000                44.104919
# 5               17.970619       -99.000000                43.816430
# 7               43.217778       -99.000000               -48.405089
# 9               41.691469        52.337026               -62.724362
# 11              44.225367        -0.600865                40.707475
#
#     engine_temperature(°C)  motor_torque(N-m)  generator_temperature(°C)  \
# 1                46.258870        2372.384119                  78.129803
# ...

# %%
df2.shape
# Out:
# (20551, 27)

# %%
plt.xlabel('shaft_temperature(°C)')
plt.ylabel('windmill_generated_power(kW/h)')
plt.scatter(df1['shaft_temperature(°C)'],df1['windmill_generated_power(kW/h)'])

# %%
df3=df1[df1['shaft_temperature(°C)']>0]

# %%
df3.shape
# Out:
# (26781, 27)

# %%
plt.scatter(df3['blades_angle(°)'],df3['windmill_generated_power(kW/h)'])

# %%
df4=df3[df3['blades_angle(°)']>=-10]

# %%
df4=df4[df4['atmospheric_temperature(°C)']>=0]
df4.shape
# Out:
# (15621, 27)

# %%
df4=df4[df4['shaft_temperature(°C)']>=0]
df4.shape
# Out:
# (15621, 27)

# %%
plt.scatter(df4['gearbox_temperature(°C)'],df4['windmill_generated_power(kW/h)'])

# %%
df4=df4[df4['gearbox_temperature(°C)']<400]
plt.scatter(df4['gearbox_temperature(°C)'],df4['windmill_generated_power(kW/h)'])

# %%
df4=df4[df4['gearbox_temperature(°C)']>-50]
df4.shape
# Out:
# (14970, 27)

# %%
df4.isnull().sum()
# Out:
# tracking_id                          0
# wind_speed(m/s)                    147
# atmospheric_temperature(°C)          0
# shaft_temperature(°C)                0
# blades_angle(°)                      0
# gearbox_temperature(°C)              0
# engine_temperature(°C)               1
# motor_torque(N-m)                    5
# generator_temperature(°C)            1
# atmospheric_pressure(Pascal)      1431
# area_temperature(°C)                 0
# windmill_body_temperature(°C)     1283
# wind_direction(°)                 2745
# resistance(ohm)                      1
# rotor_torque(N-m)                  312
# turbine_status                     944
# cloud_level                        142
# blade_length(m)                   2744
# blade_breadth(m)                     0
# windmill_height(m)                 298
# windmill_generated_power(kW/h)     109
# Y                                    0
# M                                    0
# D                                    0
# ...

# %%
df4.shape
# Out:
# (14970, 27)

# %%
df4=df4[df4['atmospheric_pressure(Pascal)']>-10]

# %%
df4=df4[df4['windmill_body_temperature(°C)']>-90]

# %%
df4[df4['blades_angle(°)']>0]
# Out:
#       tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 26          19376        94.383942                    19.958514
# 30          24217        91.673080                    16.935292
# 32          29287        91.259640                    16.422512
# 33          10034        92.895533                    21.404675
# 46          20213       -93.682436                    24.417417
# ...           ...              ...                          ...
# 28189       36231        95.357037                    34.005698
# 28194       21441        13.096694                     9.936019
# 28195        7814        94.765699                    23.576793
# 28197        5193        94.160463                    28.674296
# 28198       12173        95.430377                    26.560254
#
#        shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 26                 44.327188         0.664472                41.828836
# ...

# %%
df4['blades_angle(°)']=df4['blades_angle(°)'].apply(lambda x: x if x>=0 else (180+x))
df4
# Out:
#       tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 11           2506        92.774351                    15.843846
# 20           5591       213.154451                    35.612077
# 26          19376        94.383942                    19.958514
# 29          40134        93.896679                    23.562381
# 30          24217        91.673080                    16.935292
# ...           ...              ...                          ...
# 28193       32913        95.033031                    28.054138
# 28194       21441        13.096694                     9.936019
# 28195        7814        94.765699                    23.576793
# 28197        5193        94.160463                    28.674296
# 28198       12173        95.430377                    26.560254
#
#        shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 11                 44.225367       179.399135                40.707475
# ...

# %%
df4.isnull().sum()
# Out:
# tracking_id                          0
# wind_speed(m/s)                     84
# atmospheric_temperature(°C)          0
# shaft_temperature(°C)                0
# blades_angle(°)                      0
# gearbox_temperature(°C)              0
# engine_temperature(°C)               0
# motor_torque(N-m)                    2
# generator_temperature(°C)            0
# atmospheric_pressure(Pascal)         0
# area_temperature(°C)                 0
# windmill_body_temperature(°C)        0
# wind_direction(°)                 1649
# resistance(ohm)                      0
# rotor_torque(N-m)                  172
# turbine_status                     584
# cloud_level                         88
# blade_length(m)                   1675
# blade_breadth(m)                     0
# windmill_height(m)                 186
# windmill_generated_power(kW/h)      71
# Y                                    0
# M                                    0
# D                                    0
# ...

# %%
df4=df4[df4['windmill_body_temperature(°C)']>-10]

# %%
df4.head(10)
# Out:
#    tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 20        5591       213.154451                    35.612077
# 26       19376        94.383942                    19.958514
# 29       40134        93.896679                    23.562381
# 30       24217        91.673080                    16.935292
# 32       29287        91.259640                    16.422512
# 33       10034        92.895533                    21.404675
# 40       36147        24.153914                     4.676663
# 42       28808        31.470933                    11.306421
# 46       20213       -93.682436                    24.417417
# 50        8096        41.176352                    10.674392
#
#     shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 20              42.710523       179.163595                34.211340
# 26              44.327188         0.664472                41.828836
# 29              47.511977       178.903808               156.431353
# ...

# %%
df4.isnull().sum()
# Out:
# tracking_id                          0
# wind_speed(m/s)                     83
# atmospheric_temperature(°C)          0
# shaft_temperature(°C)                0
# blades_angle(°)                      0
# gearbox_temperature(°C)              0
# engine_temperature(°C)               0
# motor_torque(N-m)                    2
# generator_temperature(°C)            0
# atmospheric_pressure(Pascal)         0
# area_temperature(°C)                 0
# windmill_body_temperature(°C)        0
# wind_direction(°)                 1633
# resistance(ohm)                      0
# rotor_torque(N-m)                  169
# turbine_status                     574
# cloud_level                         88
# blade_length(m)                   1653
# blade_breadth(m)                     0
# windmill_height(m)                 185
# windmill_generated_power(kW/h)      70
# Y                                    0
# M                                    0
# D                                    0
# ...

# %%
df4['wind_direction(°)']=df4['wind_direction(°)'].fillna(np.mean(df4['wind_direction(°)']))
# Out:
# <ipython-input-70-b7256cfabb6e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['wind_direction(°)']=df4['wind_direction(°)'].fillna(np.mean(df4['wind_direction(°)']))

# %%
df4['blade_length(m)']=df4['blade_length(m)'].fillna(np.mean(df4['blade_length(m)']))
# Out:
# <ipython-input-71-9f7075a54b60>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['blade_length(m)']=df4['blade_length(m)'].fillna(np.mean(df4['blade_length(m)']))

# %%
df4.isnull().sum()
# Out:
# tracking_id                         0
# wind_speed(m/s)                    83
# atmospheric_temperature(°C)         0
# shaft_temperature(°C)               0
# blades_angle(°)                     0
# gearbox_temperature(°C)             0
# engine_temperature(°C)              0
# motor_torque(N-m)                   2
# generator_temperature(°C)           0
# atmospheric_pressure(Pascal)        0
# area_temperature(°C)                0
# windmill_body_temperature(°C)       0
# wind_direction(°)                   0
# resistance(ohm)                     0
# rotor_torque(N-m)                 169
# turbine_status                    574
# cloud_level                        88
# blade_length(m)                     0
# blade_breadth(m)                    0
# windmill_height(m)                185
# windmill_generated_power(kW/h)     70
# Y                                   0
# M                                   0
# D                                   0
# H                                   0
# ...

# %%
df4['rotor_torque(N-m)']=df4['rotor_torque(N-m)'].fillna(np.mean(df4['rotor_torque(N-m)']))
# Out:
# <ipython-input-73-d136b0030f98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['rotor_torque(N-m)']=df4['rotor_torque(N-m)'].fillna(np.mean(df4['rotor_torque(N-m)']))

# %%
df4['turbine_status'].head().unique()
# Out:
# array(['ABC', 'BA', 'AB', 'BBB', 'BB'], dtype=object)

# %%
df4['windmill_height(m)']=df4['windmill_height(m)'].fillna(np.mean(df4['windmill_height(m)']))
# Out:
# <ipython-input-78-4ee023cdaf9f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['windmill_height(m)']=df4['windmill_height(m)'].fillna(np.mean(df4['windmill_height(m)']))

# %%
df4.isnull().sum()
# Out:
# tracking_id                         0
# wind_speed(m/s)                    83
# atmospheric_temperature(°C)         0
# shaft_temperature(°C)               0
# blades_angle(°)                     0
# gearbox_temperature(°C)             0
# engine_temperature(°C)              0
# motor_torque(N-m)                   2
# generator_temperature(°C)           0
# atmospheric_pressure(Pascal)        0
# area_temperature(°C)                0
# windmill_body_temperature(°C)       0
# wind_direction(°)                   0
# resistance(ohm)                     0
# rotor_torque(N-m)                   0
# turbine_status                    574
# cloud_level                        88
# blade_length(m)                     0
# blade_breadth(m)                    0
# windmill_height(m)                  0
# windmill_generated_power(kW/h)     70
# Y                                   0
# M                                   0
# D                                   0
# H                                   0
# ...

# %%
df4['wind_speed(m/s)']=df4['wind_speed(m/s)'].fillna(np.mean(df4['wind_speed(m/s)']))
# Out:
# <ipython-input-80-209675f82743>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['wind_speed(m/s)']=df4['wind_speed(m/s)'].fillna(np.mean(df4['wind_speed(m/s)']))

# %%
df4.shape
# Out:
# (9034, 27)

# %%
df4.isnull().sum()
# Out:
# tracking_id                         0
# wind_speed(m/s)                     0
# atmospheric_temperature(°C)         0
# shaft_temperature(°C)               0
# blades_angle(°)                     0
# gearbox_temperature(°C)             0
# engine_temperature(°C)              0
# motor_torque(N-m)                   2
# generator_temperature(°C)           0
# atmospheric_pressure(Pascal)        0
# area_temperature(°C)                0
# windmill_body_temperature(°C)       0
# wind_direction(°)                   0
# resistance(ohm)                     0
# rotor_torque(N-m)                   0
# turbine_status                    574
# cloud_level                        88
# blade_length(m)                     0
# blade_breadth(m)                    0
# windmill_height(m)                  0
# windmill_generated_power(kW/h)     70
# Y                                   0
# M                                   0
# D                                   0
# H                                   0
# ...

# %%
df4['cloud_level'].unique()
# Out:
# array(['Medium', 'Low', 'Extremely Low', nan], dtype=object)

# %%
maping={
    'Medium':3,
    'Low':2,
    'Extremely Low':1
}
df4['cloud_level']=df4['cloud_level'].map(maping)
# Out:
# <ipython-input-86-7094952d0452>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['cloud_level']=df4['cloud_level'].map(maping)

# %%
df4['turbine_status'].unique()
# Out:
# array(['ABC', 'BA', 'AB', 'BBB', 'BB', 'AAA', 'D', 'AC', nan, 'A2', 'BCB',
#        'B', 'B2', 'BD', 'A'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()
l.fit_transform(df4['turbine_status'])
# Out:
# array([ 4,  8,  3, ...,  9, 13, 11])

# %%
df4['Label_turbine_status']=l.fit_transform(df4['turbine_status'])
df4.head()
# Out:
# <ipython-input-93-54cdcda09df4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Label_turbine_status']=l.fit_transform(df4['turbine_status'])
#    tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 20        5591       213.154451                    35.612077
# 26       19376        94.383942                    19.958514
# 29       40134        93.896679                    23.562381
# 30       24217        91.673080                    16.935292
# 32       29287        91.259640                    16.422512
#
#     shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 20              42.710523       179.163595                34.211340
# 26              44.327188         0.664472                41.828836
# ...

# %%
df4.isnull().sum()
# Out:
# tracking_id                         0
# wind_speed(m/s)                     0
# atmospheric_temperature(°C)         0
# shaft_temperature(°C)               0
# blades_angle(°)                     0
# gearbox_temperature(°C)             0
# engine_temperature(°C)              0
# motor_torque(N-m)                   2
# generator_temperature(°C)           0
# atmospheric_pressure(Pascal)        0
# area_temperature(°C)                0
# windmill_body_temperature(°C)       0
# wind_direction(°)                   0
# resistance(ohm)                     0
# rotor_torque(N-m)                   0
# turbine_status                    574
# cloud_level                        88
# blade_length(m)                     0
# blade_breadth(m)                    0
# windmill_height(m)                  0
# windmill_generated_power(kW/h)     70
# Y                                   0
# M                                   0
# D                                   0
# H                                   0
# ...

# %%
df4['motor_torque(N-m)']=df4['motor_torque(N-m)'].fillna(np.mean(df4['motor_torque(N-m)']))
# Out:
# <ipython-input-95-6a5e2e1011d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['motor_torque(N-m)']=df4['motor_torque(N-m)'].fillna(np.mean(df4['motor_torque(N-m)']))

# %%
import math
df4['cloud_level']=df4['cloud_level'].fillna((np.median(df4['cloud_level'])))
# Out:
# <ipython-input-97-b0d497862e2b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['cloud_level']=df4['cloud_level'].fillna((np.median(df4['cloud_level'])))

# %%
df4.isna().sum()
df4.shape
# Out:
# (9034, 28)

# %%
df5=df4.dropna()
df5.shape
# Out:
# (8314, 28)

# %%
df5.isnull().sum()
# Out:
# tracking_id                       0
# wind_speed(m/s)                   0
# atmospheric_temperature(°C)       0
# shaft_temperature(°C)             0
# blades_angle(°)                   0
# gearbox_temperature(°C)           0
# engine_temperature(°C)            0
# motor_torque(N-m)                 0
# generator_temperature(°C)         0
# atmospheric_pressure(Pascal)      0
# area_temperature(°C)              0
# windmill_body_temperature(°C)     0
# wind_direction(°)                 0
# resistance(ohm)                   0
# rotor_torque(N-m)                 0
# turbine_status                    0
# cloud_level                       0
# blade_length(m)                   0
# blade_breadth(m)                  0
# windmill_height(m)                0
# windmill_generated_power(kW/h)    0
# Y                                 0
# M                                 0
# D                                 0
# H                                 0
# Min                               0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
df5.columns
# Out:
# Index(['tracking_id', 'wind_speed(m/s)', 'atmospheric_temperature(°C)',
#        'shaft_temperature(°C)', 'blades_angle(°)', 'gearbox_temperature(°C)',
#        'engine_temperature(°C)', 'motor_torque(N-m)',
#        'generator_temperature(°C)', 'atmospheric_pressure(Pascal)',
#        'area_temperature(°C)', 'windmill_body_temperature(°C)',
#        'wind_direction(°)', 'resistance(ohm)', 'rotor_torque(N-m)',
#        'turbine_status', 'cloud_level', 'blade_length(m)', 'blade_breadth(m)',
#        'windmill_height(m)', 'windmill_generated_power(kW/h)', 'Y', 'M', 'D',
#        'H', 'Min', 'S', 'Label_turbine_status'],
#       dtype='object')

# %%
x=df5.drop(['turbine_status','windmill_generated_power(kW/h)'],axis='columns')
x.head()
# Out:
#    tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 20        5591       213.154451                    35.612077
# 26       19376        94.383942                    19.958514
# 29       40134        93.896679                    23.562381
# 30       24217        91.673080                    16.935292
# 32       29287        91.259640                    16.422512
#
#     shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 20              42.710523       179.163595                34.211340
# 26              44.327188         0.664472                41.828836
# 29              47.511977       178.903808               156.431353
# 30              43.398399         0.744362                82.180146
# 32              22.520612         2.897473                91.578423
#
#     engine_temperature(°C)  motor_torque(N-m)  generator_temperature(°C)  \
# 20               41.542109        2388.033761                  73.509399
# ...

# %%
y=df5['windmill_generated_power(kW/h)']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
L_reg=LinearRegression()
L_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
L_reg.score(x_test,y_test)
# Out:
# 0.5093727658281532

# %%
from sklearn.tree import DecisionTreeRegressor
Dec_tree=DecisionTreeRegressor()
Dec_tree.fit(x_train,y_train)
Dec_tree.score(x_test,y_test)
# Out:
# 0.9173862946776596

# %%
import pickle
with open('model','ab') as f:
    pickle.dump(Dec_tree,f)

# %%
df6=test_df
df6.head()
# Out:
#   tracking_id             datetime  wind_speed(m/s)  \
# 0    WM_19817  2019-04-17 08:53:20        94.324266
# 1    WM_18723  2019-03-30 07:43:20        10.088870
# 2    WM_34552  2019-08-10 11:33:20       347.152090
# 3    WM_28570  2019-06-26 03:53:20        24.471997
# 4    WM_36934  2019-08-27 16:43:20        96.997026
#
#    atmospheric_temperature(°C)  shaft_temperature(°C)  blades_angle(°)  \
# 0                    17.641186              89.714193        51.146788
# 1                    13.978119              43.272846        46.516394
# 2                    31.423035              41.076640        26.931602
# 3                   -99.000000              14.375078        66.513953
# 4                    33.281836              41.405192         1.843112
#
#    gearbox_temperature(°C)  engine_temperature(°C)  motor_torque(N-m)  \
# 0                40.460560               39.594734        1073.202715
# 1                40.027788               41.176860         517.436430
# ...

# %%
df6.tracking_id=df6.tracking_id.apply(lambda x:x[3:])

# %%
df6.datetime=pd.to_datetime(df6.datetime)

# %%
df6['Y']=df6['datetime'].dt.year
df6['M']=df6['datetime'].dt.month
df6['D']=df6['datetime'].dt.day
df6['H']=df6['datetime'].dt.hour
df6['Min']=df6['datetime'].dt.minute
df6['S']=df6['datetime'].dt.second

# %%
df6['Label_turbine_status']=l.fit_transform(df6['turbine_status'])

# %%
maping={
    'Medium':3,
    'Low':2,
    'Extremely Low':1
}
df6['cloud_level']=df6['cloud_level'].map(maping)

# %%
df6.isnull().sum()
# Out:
# tracking_id                         0
# datetime                            0
# wind_speed(m/s)                   126
# atmospheric_temperature(°C)      1427
# shaft_temperature(°C)               1
# blades_angle(°)                   106
# gearbox_temperature(°C)             1
# engine_temperature(°C)              5
# motor_torque(N-m)                  11
# generator_temperature(°C)           5
# atmospheric_pressure(Pascal)     1151
# area_temperature(°C)                1
# windmill_body_temperature(°C)     926
# wind_direction(°)                2160
# resistance(ohm)                     0
# rotor_torque(N-m)                 281
# turbine_status                    797
# cloud_level                       125
# blade_length(m)                  2114
# blade_breadth(m)                    0
# windmill_height(m)                255
# Y                                   0
# M                                   0
# D                                   0
# H                                   0
# ...

# %%
df6.shape
# Out:
# (12086, 28)

# %%
df7=df6[df1['atmospheric_temperature(°C)']>=0]
df7.head()
# Out:
# <ipython-input-124-c9fe69c90a7a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df7=df6[df1['atmospheric_temperature(°C)']>=0]
#    tracking_id            datetime  wind_speed(m/s)  \
# 1        18723 2019-03-30 07:43:20        10.088870
# 5           46 2018-10-29 04:43:20        96.423067
# 7         6959 2018-12-27 01:53:20        95.135104
# 9        33379 2019-08-02 03:33:20        10.098800
# 11       38536 2019-09-10 00:23:20        95.867818
#
#     atmospheric_temperature(°C)  shaft_temperature(°C)  blades_angle(°)  \
# 1                     13.978119              43.272846        46.516394
# 5                     38.553501              98.687024       -99.000000
# 7                           NaN              46.992644       -99.000000
# 9                           NaN              44.107139        41.161890
# 11                    16.601073               8.433747        -0.874025
#
# ...

# %%
df7=df6[df6['shaft_temperature(°C)']>0]

# %%
df7=df6[df6['blades_angle(°)']>=-10]

# %%
df7=df7[df6['atmospheric_temperature(°C)']>=0]
df7.shape
# Out:
# <ipython-input-127-62fcf1056ba7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df7=df7[df6['atmospheric_temperature(°C)']>=0]
# (7131, 28)

# %%
df7['shaft_temperature(°C)'].head()
# Out:
# 0    89.714193
# 1    43.272846
# 2    41.076640
# 4    41.405192
# 8    42.988422
# Name: shaft_temperature(°C), dtype: float64

# %%
# Out:
# <ipython-input-132-b2c6975fb204>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df7=df6[df7['shaft_temperature(°C)']>=0]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-132-b2c6975fb204> in <module>
# ----> 1 df7=df6[df7['shaft_temperature(°C)']>=0]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3066         # check_bool_indexer will throw exception if Series key cannot
#    3067         # be reindexed to match DataFrame rows
# ...

# %%
df7=df6[df6['gearbox_temperature(°C)']<400]

# %%
df7=df6[df6['gearbox_temperature(°C)']>-50]

# %%
df7.shape
# Out:
# (11581, 28)

# %%
df7=df6[df6['atmospheric_pressure(Pascal)']>-10]

# %%
df7=df6[df6['windmill_body_temperature(°C)']>-90]

# %%
df7['blades_angle(°)']=df6['blades_angle(°)'].apply(lambda x: x if x>=0 else (180+x))
df7
# Out:
# <ipython-input-138-ed1cb566a133>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['blades_angle(°)']=df6['blades_angle(°)'].apply(lambda x: x if x>=0 else (180+x))
#       tracking_id            datetime  wind_speed(m/s)  \
# 0           19817 2019-04-17 08:53:20        94.324266
# 1           18723 2019-03-30 07:43:20        10.088870
# 2           34552 2019-08-10 11:33:20       347.152090
# 3           28570 2019-06-26 03:53:20        24.471997
# 6            5545 2018-12-16 15:13:20        95.932355
# ...           ...                 ...              ...
# 12081       13376 2019-02-12 11:33:20       -15.039400
# 12082        1630 2018-11-12 17:33:20        97.594116
# 12083       24703 2019-05-27 11:53:20        16.186805
# ...

# %%
df7=df6[df6['windmill_body_temperature(°C)']>-10]

# %%
df7.isnull().sum()
# Out:
# tracking_id                         0
# datetime                            0
# wind_speed(m/s)                   102
# atmospheric_temperature(°C)      1107
# shaft_temperature(°C)               1
# blades_angle(°)                    77
# gearbox_temperature(°C)             1
# engine_temperature(°C)              3
# motor_torque(N-m)                   8
# generator_temperature(°C)           3
# atmospheric_pressure(Pascal)      880
# area_temperature(°C)                0
# windmill_body_temperature(°C)       0
# wind_direction(°)                1653
# resistance(ohm)                     0
# rotor_torque(N-m)                 219
# turbine_status                    617
# cloud_level                       101
# blade_length(m)                  1609
# blade_breadth(m)                    0
# windmill_height(m)                188
# Y                                   0
# M                                   0
# D                                   0
# H                                   0
# ...

# %%
df7['wind_direction(°)']=df7['wind_direction(°)'].fillna(np.mean(df7['wind_direction(°)']))
# Out:
# <ipython-input-141-9a43fa8a37e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['wind_direction(°)']=df7['wind_direction(°)'].fillna(np.mean(df7['wind_direction(°)']))

# %%
df7['windmill_height(m)']=df7['windmill_height(m)'].fillna(np.mean(df7['windmill_height(m)']))
df7['blade_length(m)']=df7['blade_length(m)'].fillna(np.mean(df7['blade_length(m)']))
df7['cloud_level']=df7['cloud_level'].fillna(np.mean(df7['cloud_level']))
df7['rotor_torque(N-m)']=df7['rotor_torque(N-m)'].fillna(np.mean(df7['rotor_torque(N-m)']))
df7['atmospheric_pressure(Pascal)']=df7['atmospheric_pressure(Pascal)'].fillna(np.mean(df7['atmospheric_pressure(Pascal)']))
df7['blades_angle(°)']=df7['blades_angle(°)'].fillna(np.mean(df7['blades_angle(°)']))
# Out:
# <ipython-input-142-add8bf3df285>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['windmill_height(m)']=df7['windmill_height(m)'].fillna(np.mean(df7['windmill_height(m)']))
# <ipython-input-142-add8bf3df285>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['blade_length(m)']=df7['blade_length(m)'].fillna(np.mean(df7['blade_length(m)']))
# <ipython-input-142-add8bf3df285>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df7.isnull().sum()
# Out:
# tracking_id                         0
# datetime                            0
# wind_speed(m/s)                   102
# atmospheric_temperature(°C)      1107
# shaft_temperature(°C)               1
# blades_angle(°)                     0
# gearbox_temperature(°C)             1
# engine_temperature(°C)              3
# motor_torque(N-m)                   8
# generator_temperature(°C)           3
# atmospheric_pressure(Pascal)        0
# area_temperature(°C)                0
# windmill_body_temperature(°C)       0
# wind_direction(°)                   0
# resistance(ohm)                     0
# rotor_torque(N-m)                   0
# turbine_status                    617
# cloud_level                         0
# blade_length(m)                     0
# blade_breadth(m)                    0
# windmill_height(m)                  0
# Y                                   0
# M                                   0
# D                                   0
# H                                   0
# ...

# %%
df7['atmospheric_temperature(°C)']=df7['atmospheric_temperature(°C)'].fillna(np.mean(df7['atmospheric_temperature(°C)']))
df7['bwind_speed(m/s)']=df7['wind_speed(m/s)'].fillna(np.mean(df7['wind_speed(m/s)']))
# Out:
# <ipython-input-144-6a809099b4f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['atmospheric_temperature(°C)']=df7['atmospheric_temperature(°C)'].fillna(np.mean(df7['atmospheric_temperature(°C)']))
# <ipython-input-144-6a809099b4f2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['bwind_speed(m/s)']=df7['wind_speed(m/s)'].fillna(np.mean(df7['wind_speed(m/s)']))

# %%
df7.isnull().sum()
# Out:
# tracking_id                        0
# datetime                           0
# wind_speed(m/s)                  102
# atmospheric_temperature(°C)        0
# shaft_temperature(°C)              1
# blades_angle(°)                    0
# gearbox_temperature(°C)            1
# engine_temperature(°C)             3
# motor_torque(N-m)                  8
# generator_temperature(°C)          3
# atmospheric_pressure(Pascal)       0
# area_temperature(°C)               0
# windmill_body_temperature(°C)      0
# wind_direction(°)                  0
# resistance(ohm)                    0
# rotor_torque(N-m)                  0
# turbine_status                   617
# cloud_level                        0
# blade_length(m)                    0
# blade_breadth(m)                   0
# windmill_height(m)                 0
# Y                                  0
# M                                  0
# D                                  0
# H                                  0
# ...

# %%
df7.dropna()
# Out:
#       tracking_id            datetime  wind_speed(m/s)  \
# 0           19817 2019-04-17 08:53:20        94.324266
# 1           18723 2019-03-30 07:43:20        10.088870
# 2           34552 2019-08-10 11:33:20       347.152090
# 3           28570 2019-06-26 03:53:20        24.471997
# 6            5545 2018-12-16 15:13:20        95.932355
# ...           ...                 ...              ...
# 12080         375 2018-10-31 20:03:20       -52.827329
# 12082        1630 2018-11-12 17:33:20        97.594116
# 12083       24703 2019-05-27 11:53:20        16.186805
# 12084       22893 2019-05-13 21:53:20        93.254033
# 12085       14513 2019-02-20 23:43:20        42.607485
#
#        atmospheric_temperature(°C)  shaft_temperature(°C)  blades_angle(°)  \
# 0                        17.641186              89.714193        51.146788
# 1                        13.978119              43.272846        46.516394
# 2                        31.423035              41.076640        26.931602
# ...

# %%
df7.shape
# Out:
# (9342, 29)

# %%
df8=df7.dropna()
df8.shape
# Out:
# (8622, 29)

# %%
df8.isnull().sum()
# Out:
# tracking_id                      0
# datetime                         0
# wind_speed(m/s)                  0
# atmospheric_temperature(°C)      0
# shaft_temperature(°C)            0
# blades_angle(°)                  0
# gearbox_temperature(°C)          0
# engine_temperature(°C)           0
# motor_torque(N-m)                0
# generator_temperature(°C)        0
# atmospheric_pressure(Pascal)     0
# area_temperature(°C)             0
# windmill_body_temperature(°C)    0
# wind_direction(°)                0
# resistance(ohm)                  0
# rotor_torque(N-m)                0
# turbine_status                   0
# cloud_level                      0
# blade_length(m)                  0
# blade_breadth(m)                 0
# windmill_height(m)               0
# Y                                0
# M                                0
# D                                0
# H                                0
# Min                              0
# S                                0
# ...

# %%
x_test=df8.drop(['datetime','turbine_status'],axis='columns')
x_test.head()
# Out:
#   tracking_id  wind_speed(m/s)  atmospheric_temperature(°C)  \
# 0       19817        94.324266                    17.641186
# 1       18723        10.088870                    13.978119
# 2       34552       347.152090                    31.423035
# 3       28570        24.471997                   -99.000000
# 6        5545        95.932355                   -99.000000
#
#    shaft_temperature(°C)  blades_angle(°)  gearbox_temperature(°C)  \
# 0              89.714193        51.146788                40.460560
# 1              43.272846        46.516394                40.027788
# 2              41.076640        26.931602                43.109122
# 3              14.375078        66.513953                13.741253
# 6              45.337007        12.329468                42.436781
#
#    engine_temperature(°C)  motor_torque(N-m)  generator_temperature(°C)  \
# 0               39.594734        1073.202715                  66.830037
# ...

# %%
df8=df8[df8['atmospheric_temperature(°C)']>-10]

# %%
x_test=df8.drop(['datetime','turbine_status'],axis='columns')

# %%
x_train.columns
# Out:
# Index(['tracking_id', 'wind_speed(m/s)', 'atmospheric_temperature(°C)',
#        'shaft_temperature(°C)', 'blades_angle(°)', 'gearbox_temperature(°C)',
#        'engine_temperature(°C)', 'motor_torque(N-m)',
#        'generator_temperature(°C)', 'atmospheric_pressure(Pascal)',
#        'area_temperature(°C)', 'windmill_body_temperature(°C)',
#        'wind_direction(°)', 'resistance(ohm)', 'rotor_torque(N-m)',
#        'cloud_level', 'blade_length(m)', 'blade_breadth(m)',
#        'windmill_height(m)', 'Y', 'M', 'D', 'H', 'Min', 'S',
#        'Label_turbine_status'],
#       dtype='object')

# %%
x_test.columns
# Out:
# Index(['tracking_id', 'wind_speed(m/s)', 'atmospheric_temperature(°C)',
#        'shaft_temperature(°C)', 'blades_angle(°)', 'gearbox_temperature(°C)',
#        'engine_temperature(°C)', 'motor_torque(N-m)',
#        'generator_temperature(°C)', 'atmospheric_pressure(Pascal)',
#        'area_temperature(°C)', 'windmill_body_temperature(°C)',
#        'wind_direction(°)', 'resistance(ohm)', 'rotor_torque(N-m)',
#        'cloud_level', 'blade_length(m)', 'blade_breadth(m)',
#        'windmill_height(m)', 'Y', 'M', 'D', 'H', 'Min', 'S',
#        'Label_turbine_status', 'bwind_speed(m/s)'],
#       dtype='object')

# %%
x_test=x_test.drop('bwind_speed(m/s)',axis='columns')

# %%
Dec_tree.predict(x_test)
# Out:
# array([ 2.19396654,  2.14694488,  3.2159498 , ...,  4.31597983,
#         4.93209424, 10.3181843 ])

# %%
df8['windmill_generated_power(kW/h)']=Dec_tree.predict(x_test)
# Out:
# <ipython-input-161-98fe2fba1475>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8['windmill_generated_power(kW/h)']=Dec_tree.predict(x_test)

# %%
df8.columns
# Out:
# Index(['tracking_id', 'datetime', 'wind_speed(m/s)',
#        'atmospheric_temperature(°C)', 'shaft_temperature(°C)',
#        'blades_angle(°)', 'gearbox_temperature(°C)', 'engine_temperature(°C)',
#        'motor_torque(N-m)', 'generator_temperature(°C)',
#        'atmospheric_pressure(Pascal)', 'area_temperature(°C)',
#        'windmill_body_temperature(°C)', 'wind_direction(°)', 'resistance(ohm)',
#        'rotor_torque(N-m)', 'turbine_status', 'cloud_level', 'blade_length(m)',
#        'blade_breadth(m)', 'windmill_height(m)', 'Y', 'M', 'D', 'H', 'Min',
#        'S', 'Label_turbine_status', 'bwind_speed(m/s)',
#        'windmill_generated_power(kW/h)'],
#       dtype='object')

# %%
df8=df8.drop('bwind_speed(m/s)',axis='columns')

# %%
df8.columns
# Out:
# Index(['tracking_id', 'datetime', 'wind_speed(m/s)',
#        'atmospheric_temperature(°C)', 'shaft_temperature(°C)',
#        'blades_angle(°)', 'gearbox_temperature(°C)', 'engine_temperature(°C)',
#        'motor_torque(N-m)', 'generator_temperature(°C)',
#        'atmospheric_pressure(Pascal)', 'area_temperature(°C)',
#        'windmill_body_temperature(°C)', 'wind_direction(°)', 'resistance(ohm)',
#        'rotor_torque(N-m)', 'turbine_status', 'cloud_level', 'blade_length(m)',
#        'blade_breadth(m)', 'windmill_height(m)', 'Y', 'M', 'D', 'H', 'Min',
#        'S', 'Label_turbine_status', 'windmill_generated_power(kW/h)'],
#       dtype='object')

# %%
result=pd.DataFrame()

# %%
result=df8[['tracking_id','datetime','windmill_generated_power(kW/h)']]

# %%
result.head()
# Out:
#    tracking_id            datetime  windmill_generated_power(kW/h)
# 0        19817 2019-04-17 08:53:20                        2.193967
# 1        18723 2019-03-30 07:43:20                        2.146945
# 2        34552 2019-08-10 11:33:20                        3.215950
# 7         6959 2018-12-27 01:53:20                        8.863709
# 11       38536 2019-09-10 00:23:20                        8.550254

# %%
result.tracking_id=result.tracking_id.apply(lambda x: 'WM_'+x)
# Out:
# /home/rishi/.local/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
result.head()
# Out:
#    tracking_id            datetime  windmill_generated_power(kW/h)
# 0     WM_19817 2019-04-17 08:53:20                        2.193967
# 1     WM_18723 2019-03-30 07:43:20                        2.146945
# 2     WM_34552 2019-08-10 11:33:20                        3.215950
# 7      WM_6959 2018-12-27 01:53:20                        8.863709
# 11    WM_38536 2019-09-10 00:23:20                        8.550254

# %%
result.to_csv('submisssion.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-174-8eaf9d50f237> in <module>
# ----> 1 result.to_csv('submisssion.csv').shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
result_df=pd.read_csv('submisssion.csv')
result.shape
# Out:
# (7398, 3)
